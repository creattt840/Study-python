# %% [markdown]
# 作用：读取文本文件（.txt），将全部内容放入一个Document对象中。

# %%
from langchain_community.document_loaders import TextLoader

loader=TextLoader(
    "xxx.txt",
    encoding="utf-8",
)

docs=loader.load()
