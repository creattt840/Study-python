# %% [markdown]
# 中间件的作用是对智能体的每一步工作进行控制和自定义的执行。

# %% [markdown]
# ##### 作用场景：
# ##### 日志记录，分析，调试
# ##### 转换提示词，工具选择
# ##### 重试，备用，提前终止等逻辑控制
# ##### 安全防护，个人身份检测等

# %% [markdown]
# ##### 中间件通过Hooks钩子来实现拦截，自定义中间件可以简单的使用装饰器来定义
# ##### 节点式钩子（执行点顺序拦截）：
# ##### before_agent：agent执行之前拦截
# ##### after_agent：agent执行之后拦截
# ##### before_model：模型执行前拦截
# ##### after_model：模型执行后拦截
#
# ##### 针对工具和模型的包装式钩子：
# ##### wrap_model_call：每个模型调用时候拦截
# ##### warp_tool_call：每个工具调用时拦截
