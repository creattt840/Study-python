# %% [markdown]
# 添加记忆

# %% [markdown]
# 添加会话记忆分为三步：

# %% [markdown]
# 导入并初始化checkpointer

# %% [markdown]
# 创建Agent，指定checkpointer

# %% [markdown]
# 调用Agent，指定thread_id

# %%
from langchain.agents import create_agent
from langgraph.checkpoint.memory import Checkpoint, InMemorySaver

agent = create_agent(
    "deepseek-chat",
    checkpointer=InMemorySaver()
)

# %%
from langchain.messages import HumanMessage

#设定thread_id，作为会话标识
config={"configurable":{"thread_id":"thread_1"}}

#第一次调用，告知AI我的信息
response=agent.invoke(
    {"messages":[HumanMessage(content="你好，我是马里奥")]},
    config #调用时添加thread_id
)

print(response)
# Out:
# {'messages': [HumanMessage(content='你好，我是马里奥', additional_kwargs={}, response_metadata={}, id='b5198aed-efd0-413c-85ec-c29778382d46'), AIMessage(content='你好，水管工马里奥！🏁 要来点蘑菇还是星星吗？😄 需要我帮你找碧姬公主，还是聊聊如何踩扁酷霸王的诡计？', additional_kwargs={'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 39, 'prompt_tokens': 9, 'total_tokens': 48, 'completion_tokens_details': None, 'prompt_tokens_details': {'audio_tokens': None, 'cached_tokens': 0}, 'prompt_cache_hit_tokens': 0, 'prompt_cache_miss_tokens': 9}, 'model_provider': 'deepseek', 'model_name': 'deepseek-v4-flash', 'system_fingerprint': 'fp_8b330d02d0_prod0820_fp8_kvcache_20260402', 'id': 'dec4154b-ae91-4567-b3ff-366a69795431', 'finish_reason': 'stop', 'logprobs': None}, id='lc_run--019f02d4-0b4f-7731-a32c-7918c2ec87c9-0', tool_calls=[], invalid_tool_calls=[], usage_metadata={'input_tokens': 9, 'output_tokens': 39, 'total_tokens': 48, 'input_token_details': {'cache_read': 0}, 'output_token_details': {}})]}

# %%
#第二次调用，询问我的信息，这次带上thread_id，唤起记忆
response=agent.invoke(
    {"messages":[HumanMessage("我是谁？")]},
    config
)

print(response)
# Out:
# {'messages': [HumanMessage(content='你好，我是马里奥', additional_kwargs={}, response_metadata={}, id='b5198aed-efd0-413c-85ec-c29778382d46'), AIMessage(content='你好，水管工马里奥！🏁 要来点蘑菇还是星星吗？😄 需要我帮你找碧姬公主，还是聊聊如何踩扁酷霸王的诡计？', additional_kwargs={'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 39, 'prompt_tokens': 9, 'total_tokens': 48, 'completion_tokens_details': None, 'prompt_tokens_details': {'audio_tokens': None, 'cached_tokens': 0}, 'prompt_cache_hit_tokens': 0, 'prompt_cache_miss_tokens': 9}, 'model_provider': 'deepseek', 'model_name': 'deepseek-v4-flash', 'system_fingerprint': 'fp_8b330d02d0_prod0820_fp8_kvcache_20260402', 'id': 'dec4154b-ae91-4567-b3ff-366a69795431', 'finish_reason': 'stop', 'logprobs': None}, id='lc_run--019f02d4-0b4f-7731-a32c-7918c2ec87c9-0', tool_calls=[], invalid_tool_calls=[], usage_metadata={'input_tokens': 9, 'output_tokens': 39, 'total_tokens': 48, 'input_token_details': {'cache_read': 0}, 'output_token_details': {}}), HumanMessage(content='我是谁？', additional_kwargs={}, response_metadata={}, id='f19fe578-c919-4bf6-b464-94fc7abdea3b'), AIMessage(content='你是马里奥！来自蘑菇王国的传奇水管工、马力欧赛车冠军、耀西的好搭档，以及无数次拯救碧姬公主的大胡子英雄！🍄👨🏻\u200d🚒  \n\n（不过……你真是马里奥？要不要先说说你上一次吃到的超级蘑菇是什么颜色的？🌟）', additional_kwargs={'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 63, 'prompt_tokens': 55, 'total_tokens': 118, 'completion_tokens_details': None, 'prompt_tokens_details': {'audio_tokens': None, 'cached_tokens': 0}, 'prompt_cache_hit_tokens': 0, 'prompt_cache_miss_tokens': 55}, 'model_provider': 'deepseek', 'model_name': 'deepseek-v4-flash', 'system_fingerprint': 'fp_8b330d02d0_prod0820_fp8_kvcache_20260402', 'id': '107b3755-ff26-4cdb-8df7-25a7c3b9cf61', 'finish_reason': 'stop', 'logprobs': None}, id='lc_run--019f02d4-c26e-7c21-b2ee-bc580d0586a8-0', tool_calls=[], invalid_tool_calls=[], usage_metadata={'input_tokens': 55, 'output_tokens': 63, 'total_tokens': 118, 'input_token_details': {'cache_read': 0}, 'output_token_details': {}})]}

# %% [markdown]
# # Memory持久化存储

# %% [markdown]
# 如果使用Sqlite作为存储方案，首先需要按照langgraph-checkpoint-sqlite依赖：

# %% [markdown]
# uv add langgraph-checkpoint-sqlite

# %% [markdown]
# #### 接着按照以下步骤使用：
# ##### 导入依赖
# ##### 初始化checkpointer
# ##### 自动建表
# ##### 创建Agent,指定checkpointer

# %%
import sqlite3
from langgraph.checkpoint.sqlite import SqliteSaver

#连接sqlite
connection=sqlite3.connect("resources/checkpoint.db",check_same_thread=False)

#初始化checkpointer
checkpoint=SqliteSaver(connection)

#自动建表
checkpoint.setup()

#创建agent
agent=create_agent(
    "deepseek-chat",
    checkpointer=checkpoint
)

# %%
from langchain.messages import HumanMessage

#设定thread_id，作为会话标识
config={"configurable":{"thread_id":"thread_2"}}

#第一次调用
response=agent.invoke(
    {"messages":[HumanMessage("你好，我是派蒙")]},
    config
)

print(response)
# Out:
# {'messages': [HumanMessage(content='你好，我是派蒙', additional_kwargs={}, response_metadata={}, id='58f065dc-6f05-415a-9642-c4aeb3feb7b5'), AIMessage(content='你好呀，派蒙！我是DeepSeek，很高兴认识你～✨\n\n你是《原神》里那个会飞的小向导吗？还是说……你是某个旅行者身边最棒的伙伴？🤔\n\n不管怎样，有什么我可以帮你的吗？无论是聊聊提瓦特大陆的趣事，还是其他问题，我都在这里哦！😊', additional_kwargs={'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 75, 'prompt_tokens': 9, 'total_tokens': 84, 'completion_tokens_details': None, 'prompt_tokens_details': {'audio_tokens': None, 'cached_tokens': 0}, 'prompt_cache_hit_tokens': 0, 'prompt_cache_miss_tokens': 9}, 'model_provider': 'deepseek', 'model_name': 'deepseek-v4-flash', 'system_fingerprint': 'fp_8b330d02d0_prod0820_fp8_kvcache_20260402', 'id': 'c9f62617-4585-4a53-af56-a9d3922fd061', 'finish_reason': 'stop', 'logprobs': None}, id='lc_run--019f0324-4220-7872-b4cf-29c6e0567586-0', tool_calls=[], invalid_tool_calls=[], usage_metadata={'input_tokens': 9, 'output_tokens': 75, 'total_tokens': 84, 'input_token_details': {'cache_read': 0}, 'output_token_details': {}})]}

# %%
#第二次调用，询问我的信息，这次带上thread_id，唤起记忆
response=agent.invoke(
    {"messages":[HumanMessage("我是谁，你要问我什么问题呢")]},
    config
)

print(response)
# Out:
# {'messages': [HumanMessage(content='你好，我是派蒙', additional_kwargs={}, response_metadata={}, id='58f065dc-6f05-415a-9642-c4aeb3feb7b5'), AIMessage(content='你好呀，派蒙！我是DeepSeek，很高兴认识你～✨\n\n你是《原神》里那个会飞的小向导吗？还是说……你是某个旅行者身边最棒的伙伴？🤔\n\n不管怎样，有什么我可以帮你的吗？无论是聊聊提瓦特大陆的趣事，还是其他问题，我都在这里哦！😊', additional_kwargs={'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 75, 'prompt_tokens': 9, 'total_tokens': 84, 'completion_tokens_details': None, 'prompt_tokens_details': {'audio_tokens': None, 'cached_tokens': 0}, 'prompt_cache_hit_tokens': 0, 'prompt_cache_miss_tokens': 9}, 'model_provider': 'deepseek', 'model_name': 'deepseek-v4-flash', 'system_fingerprint': 'fp_8b330d02d0_prod0820_fp8_kvcache_20260402', 'id': 'c9f62617-4585-4a53-af56-a9d3922fd061', 'finish_reason': 'stop', 'logprobs': None}, id='lc_run--019f0324-4220-7872-b4cf-29c6e0567586-0', tool_calls=[], invalid_tool_calls=[], usage_metadata={'input_tokens': 9, 'output_tokens': 75, 'total_tokens': 84, 'input_token_details': {'cache_read': 0}, 'output_token_details': {}}), HumanMessage(content='我是谁，你要问我什么问题呢', additional_kwargs={}, response_metadata={}, id='66b8ec4c-fdf6-4e45-b211-baaad6a4ce15'), AIMessage(content='哈哈，派蒙当然知道你是谁啦——但为了配合这场“猜猜乐”游戏，我决定先装傻一下！😜\n\n所以，我要问的问题是：  \n**“如果《原神》里的你突然掉进提瓦特大陆，第一件想抢（划掉）……想做的事是什么？”**  \n\n（比如：立刻去蒙德城偷吃甜甜花酿鸡？还是缠着钟离先生讲岩王帝君的黑历史？）  \n\n——快回答！本向导的小本本已经准备好记录了！📝✨', additional_kwargs={'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 116, 'prompt_tokens': 95, 'total_tokens': 211, 'completion_tokens_details': None, 'prompt_tokens_details': {'audio_tokens': None, 'cached_tokens': 0}, 'prompt_cache_hit_tokens': 0, 'prompt_cache_miss_tokens': 95}, 'model_provider': 'deepseek', 'model_name': 'deepseek-v4-flash', 'system_fingerprint': 'fp_8b330d02d0_prod0820_fp8_kvcache_20260402', 'id': '8657f03a-987f-4d5b-9e59-9c510d1c64d9', 'finish_reason': 'stop', 'logprobs': None}, id='lc_run--019f0325-9668-7832-9c17-05d07c47689a-0', tool_calls=[], invalid_tool_calls=[], usage_metadata={'input_tokens': 95, 'output_tokens': 116, 'total_tokens': 211, 'input_token_details': {'cache_read': 0}, 'output_token_details': {}})]}
